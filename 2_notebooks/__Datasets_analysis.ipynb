# %%
import pandas as pd
import re
import spacy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
colors = ["#06005c",
"#6b0062",
"#ac0059",
"#dc2246",
"#f8682c",
"#ffa600"]

# %% [markdown]
# # Load

# %%
fid_list = pd.read_pickle('../0_data/fid_list.pickle')
# fid_list

# %%
fid_list.fid.unique()
# Out:
# array(['009', '411', '007', '008', '035', '036', '037', '386', '387',
#        '390', '391', '395', '396', '023', '024', '017', '026', '029',
#        '025', '028', '030', '031', '003'], dtype=object)

# %%
fid_list.query('fid == "036"')
# Out:
#      fid  pid  level  individual_level  \
# 336  036  0.0    0.0                 0
# 337  036  0.0    0.0                 1
# 338  036  0.0    0.0                 0
# 339  036  0.0    0.0                 1
# 340  036  0.0    0.0                 0
# 341  036  0.0    0.0                 1
# 342  036  0.0    0.0                 0
# 343  036  0.0    0.0                 1
# 344  036  0.0    0.0                 0
# 345  036  0.0    0.0                 1
# 346  036  0.0    0.0                 0
# 347  036  0.0    0.0                 1
# 348  036  0.0    0.0                 0
# 349  036  0.0    0.0                 1
# 350  036  0.0    0.0                 0
# 351  036  0.0    0.0                 1
# 352  036  0.0    0.0                 0
# 353  036  0.0    0.0                 1
# 354  036  0.0    0.0                 1
# 355  036  0.0    0.0                 1
# 356  036  0.0    0.0                 1
# 357  036  0.0    0.0                 1
# 358  036  0.0    0.0                 1
# 359  036  0.0    0.0                 1
# 360  036  0.0    0.0                 1
# 361  036  0.0    0.0                 1
# 362  036  0.0    0.0                 1
# 363  036  0.0    0.0                 1
# 364  036  0.0    0.0                 1
# 365  036  0.0    0.0                 1
# 366  036  0.0    0.0                 1
# 367  036  0.0    0.0                 1
# 368  036  0.0    0.0                 1
# 369  036  0.0    0.0                 1
# 370  036  0.0    0.0                 1
# 371  036  0.0    0.0                 1
# 372  036  0.0    0.0                 1
# 373  036  0.0    0.0                 1
# 374  036  0.0    0.0                 1
# 375  036  0.0    0.0                 1
# 376  036  0.0    0.0                 1
# 377  036  0.0    0.0                 1
# 378  036  0.0    0.0                 1
# 379  036  0.0    0.0                 1
# 380  036  0.0    0.0                 1
#
#                                              fs_answer
# 336  Positius:\n-Permetrà conèixer millor els alumn...
# 337  Crec que la tecnologia ja és bastant present e...
# 338  La evolución de la tecnología siempre y cuando...
# 339  La evolución de la tecnología siempre y cuando...
# 340  Toda evolución tecnológica puede ser tanto neg...
# 341  En un futuro será posible que nuestros hijos t...
# 342  L'evolució tecnològica en un primer moment hau...
# 343  L'evolució tecnològica en un primer moment hau...
# 344  Aspectes Positius:\n\n- Aprenentatge més didàc...
# 345  Positivos:\r\n- métodos eficaces y rápidos \r\...
# 346  Malo:\n- Se pueden recopilar muchos datos sens...
# 347  Malo:\r\n- Se pueden recopilar muchos datos se...
# 348  Tres beneficios múltiples visibles de la tecno...
# 349  pros:\r\n- educación personalizada\r\n- mas ca...
# 350  En un futur la tecnologia estarà molt més pres...
# 351  En el futur tot el entorn de la educació estar...
# 352  La tecnologia permetrà un més senzill accés a ...
# 353  La evolución de la tecnología hará que haya me...
# 354  Positius:\r\n-Permetrà conèixer millor els alu...
# 355  Aspectes positius:\r\n- Poden tenir tot el tem...
# 356  Aspectes positius:\r\n-Més facilitat a l'hora ...
# 357  - noves tècniques d estudi, poder reslitzar tr...
# 358  Positivo:\r\n- Mayor afinidad con las nuevas t...
# 359  ASPECTES POSITIUS:\r\n   -Permeten la creació ...
# 360  Aspectes positius:\r\n\r\n- La tecnologia farà...
# 361  En un futur la tecnologia estarà molt més pres...
# 362  La tecnologia permetrà un més senzill accés a ...
# 363  + beneficioso a cualquier sector \r\n\r\n- ine...
# 364  Positius:\r\n- Mètodes d'aprenentatge personal...
# 365  Aspectes positius:\r\n— Els infants podran exp...
# 366  + Mayor accesibilidad para la educación\r\n+ M...
# 367  Aspectes Positius:\r\n\r\n- Aprenentatge més d...
# 368  +\r\nAcceso a mucha más información gracias a ...
# 369  Tres beneficios múltiples visibles de la tecno...
# 370  La pot perjudicar el fet que les tecnològics c...
# 371  Com a aspectes positius tenim les facilitats a...
# 372  Positius:\r\n-Pots adaptar el model a cada alu...
# 373  postitivos:\r\nestará más personalizado\r\nten...
# 374  La tecnología es una herramienta que puede lle...
# 375  La tecnologia puede aportar herramientas y con...
# 376  Yo creo que depende de como se maneje y se reg...
# 377  La evolución tecnológica mayoritariamente será...
# 378  Millores:\r\n- educació mes personalitzada i i...
# 379  aspectius positius:\r\n\r\nAquelles feines rep...
# 380  El principal avantatge sería la tutoría person...

# %% [markdown]
# # Preprocess answers

# %%
# Remove non characters
fid_list['standarized'] = fid_list['fs_answer'].apply(lambda x: re.sub(r'[\n\r\b\t\f\+-]', '', x))
# Lowercase
fid_list['standarized'] = fid_list['standarized'].apply(lambda x: x.lower())
# fid_list

# %% [markdown]
# # Detect language

# %%
import spacy
from spacy.tokens import Token
from spacy.language import Language
from negspacy.negation import Negex

# DETECT LANGUAGE
def get_lang_detector(nlp, name):
    return LanguageDetector(seed=42)  # We use the seed 42
Language.factory("language_detector", func=get_lang_detector)

from spacy_language_detection import LanguageDetector

# %%
nlp_model = spacy.load("en_core_web_sm")

nlp_model.add_pipe('language_detector', last=True)

fid_list['lang'] = fid_list['standarized'].apply(lambda x: nlp_model(x)._.language['language'])
# fid_list

# %%
fid_list.loc[~fid_list['lang'].isin(['en', 'es', 'ca']), 'lang'] = 'en'

# %% [markdown]
# # Process documents

# %%
nlp_models = {
    'en': spacy.load('en_core_web_lg'),
    'es': spacy.load('es_core_news_lg'),
    'ca': spacy.load('ca_core_news_lg')
}
# DETECT NEGATIONS
for model in nlp_models.values():
    model.add_pipe("negex")
    
# DETECT NON ALPHANUMERIC
def get_excluded(token):
    # Getter function to determine if the token is excluded
    return bool(re.match(r'\W+', token.text))
Token.set_extension('is_excluded', getter=get_excluded, force=True)

def process_document(text, language):
    doc = nlp_models[language](text)
    return doc

# %%
fid_list['doc'] = fid_list.apply(lambda x: process_document(x['standarized'], x['lang']), axis=1)
fid_list
# Out:
#      fid  pid  level  individual_level  \
# 0    009  0.0    0.0                 0
# 1    009  0.0    0.0                 0
# 2    009  0.0    0.0                 1
# 3    009  0.0    0.0                 0
# 4    009  0.0    0.0                 1
# ..   ...  ...    ...               ...
# 944  003  NaN    NaN                 0
# 945  003  NaN    NaN                 0
# 946  003  NaN    NaN                 0
# 947  003  NaN    NaN                 0
# 948  003  NaN    NaN                 0
#
#                                              fs_answer  \
# 0    Technological evolution is a non-stop and real...
# 1    Positive aspects: \n\n1-In the future, with Ar...
# 2    Positive:\r\nIt could improve getting on the s...
# 3    POSITIVES:\n- Better understanding of the worl...
# 4    Positive aspects are, first of all, the way ev...
# ..                                                 ...
# 944  There are lots of different opinions and diffe...
# 945  Increased readability, reduced complexity and ...
# 946  High cohesion - used to make a code more under...
# 947  I will consider the answer and compare it with...
# 948  By further analyzing it will be easy to answer...
#
#                                            standarized lang  \
# 0    technological evolution is a nonstop and real ...   en
# 1    positive aspects: 1in the future, with artific...   en
# 2    positive:it could improve getting on the sched...   en
# 3    positives: better understanding of the world t...   en
# 4    positive aspects are, first of all, the way ev...   en
# ..                                                 ...  ...
# 944  there are lots of different opinions and diffe...   en
# 945  increased readability, reduced complexity and ...   en
# 946  high cohesion  used to make a code more unders...   en
# 947  i will consider the answer and compare it with...   en
# 948  by further analyzing it will be easy to answer...   en
#
#                                                    doc
# 0    (technological, evolution, is, a, nonstop, and...
# 1    (positive, aspects, :, 1, in, the, future, ,, ...
# 2    (positive, :, it, could, improve, getting, on,...
# 3    (positives, :, better, understanding, of, the,...
# 4    (positive, aspects, are, ,, first, of, all, ,,...
# ..                                                 ...
# 944  (there, are, lots, of, different, opinions, an...
# 945  (increased, readability, ,, reduced, complexit...
# 946  (high, cohesion,  , used, to, make, a, code, m...
# 947  (i, will, consider, the, answer, and, compare,...
# 948  (by, further, analyzing, it, will, be, easy, t...
#
# [949 rows x 8 columns]

# %% [markdown]
# # Answer length

# %%
fid_list['length'] = fid_list.doc.apply(len)
fid_list['length_clean'] = fid_list.doc.apply(lambda x: len([token for token in x if not token._.is_excluded]))
fid_list['length_special'] = fid_list.doc.apply(lambda x: len([token for token in x if token._.is_excluded]))
fid_list
# Out:
#      fid  pid  level  individual_level  \
# 0    009  0.0    0.0                 0
# 1    009  0.0    0.0                 0
# 2    009  0.0    0.0                 1
# 3    009  0.0    0.0                 0
# 4    009  0.0    0.0                 1
# ..   ...  ...    ...               ...
# 944  003  NaN    NaN                 0
# 945  003  NaN    NaN                 0
# 946  003  NaN    NaN                 0
# 947  003  NaN    NaN                 0
# 948  003  NaN    NaN                 0
#
#                                              fs_answer  \
# 0    Technological evolution is a non-stop and real...
# 1    Positive aspects: \n\n1-In the future, with Ar...
# 2    Positive:\r\nIt could improve getting on the s...
# 3    POSITIVES:\n- Better understanding of the worl...
# 4    Positive aspects are, first of all, the way ev...
# ..                                                 ...
# 944  There are lots of different opinions and diffe...
# 945  Increased readability, reduced complexity and ...
# 946  High cohesion - used to make a code more under...
# 947  I will consider the answer and compare it with...
# 948  By further analyzing it will be easy to answer...
#
#                                            standarized lang  \
# 0    technological evolution is a nonstop and real ...   en
# 1    positive aspects: 1in the future, with artific...   en
# 2    positive:it could improve getting on the sched...   en
# 3    positives: better understanding of the world t...   en
# 4    positive aspects are, first of all, the way ev...   en
# ..                                                 ...  ...
# 944  there are lots of different opinions and diffe...   en
# 945  increased readability, reduced complexity and ...   en
# 946  high cohesion  used to make a code more unders...   en
# 947  i will consider the answer and compare it with...   en
# 948  by further analyzing it will be easy to answer...   en
#
#                                                    doc  length  length_clean  \
# 0    (technological, evolution, is, a, nonstop, and...     276           253
# 1    (positive, aspects, :, 1, in, the, future, ,, ...     204           186
# 2    (positive, :, it, could, improve, getting, on,...      58            56
# 3    (positives, :, better, understanding, of, the,...     159           147
# 4    (positive, aspects, are, ,, first, of, all, ,,...     141           132
# ..                                                 ...     ...           ...
# 944  (there, are, lots, of, different, opinions, an...      23            21
# 945  (increased, readability, ,, reduced, complexit...      12            10
# 946  (high, cohesion,  , used, to, make, a, code, m...      48            44
# 947  (i, will, consider, the, answer, and, compare,...      23            22
# 948  (by, further, analyzing, it, will, be, easy, t...      24            24
#
#      length_special
# 0                23
# 1                18
# 2                 2
# 3                12
# 4                 9
# ..              ...
# 944               2
# 945               2
# 946               4
# 947               1
# 948               0
#
# [949 rows x 11 columns]

# %%
fid_list.fid.unique()
# Out:
# array(['009', '411', '007', '008', '035', '036', '037', '386', '387',
#        '390', '391', '395', '396', '023', '024', '017', '026', '029',
#        '025', '028', '030', '031', '003'], dtype=object)

# %% [markdown]
# # Main statistics

# %%
fid_statistics = pd.DataFrame(index=fid_list.fid.unique()).sort_index()
fid_statistics['n_answers'] = fid_list.groupby('fid').fs_answer.count().sort_index()
fid_statistics['average_length'] = fid_list.groupby('fid').length_clean.mean().sort_index()
fid_statistics['lang'] = fid_list.groupby('fid').lang.unique().apply(list).sort_index()
fid_statistics
# Out:
#      n_answers  average_length          lang
# 003         22       24.863636          [en]
# 007         92       97.304348      [es, ca]
# 008         90       93.944444      [ca, es]
# 009         82      121.939024          [en]
# 017         49       41.897959          [en]
# 023         32       36.031250      [es, ca]
# 024         37       27.216216      [ca, es]
# 025         65       94.800000          [en]
# 026         10       60.300000      [ca, es]
# 028         51       58.411765          [en]
# 029         24       92.333333      [es, ca]
# 030         41       46.341463      [es, ca]
# 031         54       62.629630      [ca, es]
# 035         64       78.687500      [es, ca]
# 036         45       70.444444      [ca, es]
# 037         85      107.941176          [en]
# 386         22      120.409091          [en]
# 387         20       52.150000      [en, es]
# 390         13       43.307692          [en]
# 391          9       43.000000          [en]
# 395         18       24.833333  [en, es, ca]
# 396         16       24.812500          [en]
# 411          8      128.250000          [en]

# %% [markdown]
# ## KDE length

# %%
# Add task type
task_type = ["Closed", "Open", "Open", "Open", "Open", "Open", "Open", "Open", "Open", "Closed", "Open", "Closed", "Closed", "Open", "Open", "Open", "Closed", "Closed", "Closed", "Closed", "Closed", "Closed", "Open"]
task_id = [8,1,1,1,5,5,5,6,6,7,6,7,7,1,1,1,2,2,3,4,2,2,1]
fid_statistics['task_id'] = task_id
fid_statistics['task_type'] = task_type
fid_statistics
# Out:
#      n_answers  average_length          lang  task_id task_type
# 003         22       24.863636          [en]        8    Closed
# 007         92       97.304348      [es, ca]        1      Open
# 008         90       93.944444      [ca, es]        1      Open
# 009         82      121.939024          [en]        1      Open
# 017         49       41.897959          [en]        5      Open
# 023         32       36.031250      [es, ca]        5      Open
# 024         37       27.216216      [ca, es]        5      Open
# 025         65       94.800000          [en]        6      Open
# 026         10       60.300000      [ca, es]        6      Open
# 028         51       58.411765          [en]        7    Closed
# 029         24       92.333333      [es, ca]        6      Open
# 030         41       46.341463      [es, ca]        7    Closed
# 031         54       62.629630      [ca, es]        7    Closed
# 035         64       78.687500      [es, ca]        1      Open
# 036         45       70.444444      [ca, es]        1      Open
# 037         85      107.941176          [en]        1      Open
# 386         22      120.409091          [en]        2    Closed
# 387         20       52.150000      [en, es]        2    Closed
# 390         13       43.307692          [en]        3    Closed
# 391          9       43.000000          [en]        4    Closed
# 395         18       24.833333  [en, es, ca]        2    Closed
# 396         16       24.812500          [en]        2    Closed
# 411          8      128.250000          [en]        1      Open

# %%
fid_list['task_type'] = pd.merge(left=fid_list, right=fid_statistics, left_on='fid', right_index=True, how='left')['task_type']
fid_list
# Out:
#      fid  pid  level  individual_level  \
# 0    009  0.0    0.0                 0
# 1    009  0.0    0.0                 0
# 2    009  0.0    0.0                 1
# 3    009  0.0    0.0                 0
# 4    009  0.0    0.0                 1
# ..   ...  ...    ...               ...
# 944  003  NaN    NaN                 0
# 945  003  NaN    NaN                 0
# 946  003  NaN    NaN                 0
# 947  003  NaN    NaN                 0
# 948  003  NaN    NaN                 0
#
#                                              fs_answer  \
# 0    Technological evolution is a non-stop and real...
# 1    Positive aspects: \n\n1-In the future, with Ar...
# 2    Positive:\r\nIt could improve getting on the s...
# 3    POSITIVES:\n- Better understanding of the worl...
# 4    Positive aspects are, first of all, the way ev...
# ..                                                 ...
# 944  There are lots of different opinions and diffe...
# 945  Increased readability, reduced complexity and ...
# 946  High cohesion - used to make a code more under...
# 947  I will consider the answer and compare it with...
# 948  By further analyzing it will be easy to answer...
#
#                                            standarized lang  \
# 0    technological evolution is a nonstop and real ...   en
# 1    positive aspects: 1in the future, with artific...   en
# 2    positive:it could improve getting on the sched...   en
# 3    positives: better understanding of the world t...   en
# 4    positive aspects are, first of all, the way ev...   en
# ..                                                 ...  ...
# 944  there are lots of different opinions and diffe...   en
# 945  increased readability, reduced complexity and ...   en
# 946  high cohesion  used to make a code more unders...   en
# 947  i will consider the answer and compare it with...   en
# 948  by further analyzing it will be easy to answer...   en
#
#                                                    doc  length  length_clean  \
# 0    (technological, evolution, is, a, nonstop, and...     276           253
# 1    (positive, aspects, :, 1, in, the, future, ,, ...     204           186
# 2    (positive, :, it, could, improve, getting, on,...      58            56
# 3    (positives, :, better, understanding, of, the,...     159           147
# 4    (positive, aspects, are, ,, first, of, all, ,,...     141           132
# ..                                                 ...     ...           ...
# 944  (there, are, lots, of, different, opinions, an...      23            21
# 945  (increased, readability, ,, reduced, complexit...      12            10
# 946  (high, cohesion,  , used, to, make, a, code, m...      48            44
# 947  (i, will, consider, the, answer, and, compare,...      23            22
# 948  (by, further, analyzing, it, will, be, easy, t...      24            24
#
#      length_special task_type
# 0                23      Open
# 1                18      Open
# 2                 2      Open
# 3                12      Open
# 4                 9      Open
# ..              ...       ...
# 944               2    Closed
# 945               2    Closed
# 946               4    Closed
# 947               1    Closed
# 948               0    Closed
#
# [949 rows x 12 columns]

# %%
def plot_days(city, calc_set):
    data = build_data_frame(city, calc_set)
    fig, ax = plt.subplots()
    
    sns.barplot(data=data, x='Dia', y=f'{city} data', hue='period', ax=ax)
    sns.lineplot(data=data, x='Dia', y='España Actual', label='España Actual', color=barplot_colors[2], marker='o', markerfacecolor='white', markeredgecolor=barplot_colors[2])
    
    # Adjust the width of each group
    bars = plt.gca().patches
    for i, bar in enumerate(bars):
        idx = int(np.floor(i/7))
        if idx == 0:
            x = bar.get_x()
            bar.set_x(x + 0.25)
        bar.set_width(bins_widths[idx])
        bar.set_color(barplot_colors[idx])
        x = bar.get_x()
        bar.set_x(x - bins_widths[1]/2)
        
    ax.yaxis.set_major_formatter(mtick.PercentFormatter())
    plt.ylabel('porcentage de ocupación')
    plt.xlabel('')
    plt.ylim(0, 60)
    ax.set_axisbelow(True)
    ax.yaxis.grid(True, color=barplot_colors[3])
    sns.despine(fig)
    handles, labels = ax.get_legend_handles_labels()
    legend = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=len(labels), frameon=False)

    plt.show()

# %%
type_color = {
    'Closed': colors[0],
    'Open': colors[-1]
}
fig, ax = plt.subplots()
sns.barplot(fid_statistics.sort_values(by='average_length').reset_index(), y='average_length', x='index', ax=ax)
# Adjust the width of each group
bars = plt.gca().patches
for i, bar in enumerate(bars):
    task_type = fid_statistics.task_type[i]
    bar.set_color(type_color[task_type])
handles, labels = ax.get_legend_handles_labels()
for label, color in type_color.items():
    patch = Patch(color=color)
    handles.append(patch)
    labels.append(label)
legend = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=len(labels), frameon=False)
plt.ylabel('Average answer length')
plt.xlabel('Activity')
plt.title("Tasks average length")
plt.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=False)
plt.show()

# %%
labels
# Out:
# ['Closed', 'Open']

# %%
fig, ax = plt.subplots()
for task, task_data in fid_list.groupby('fid'):
    sns.kdeplot(task_data, x='length_clean', color=type_color[fid_statistics.task_type.loc[task]])
handles, labels = ax.get_legend_handles_labels()
for label, color in type_color.items():
    print('a')
    patch = Line2D([0], [0], lw=1.5, color=color)
    handles.append(patch)
    labels.append(label)
legend = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=len(labels), frameon=False)
plt.xlabel('answer length')
plt.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
plt.show()
# Out:
# a
# a

# %%
fig, ax = plt.subplots()
for task_type, task_data in fid_list.groupby('task_type'):
    sns.kdeplot(task_data, x='length_clean', color=type_color[task_type], label=task_type)
handles, labels = ax.get_legend_handles_labels()
legend = ax.legend(handles, labels, loc='upper center', bbox_to_anchor=(0.5, 1.15), ncol=len(labels), frameon=False)
plt.xlabel('answer length')
plt.tick_params(axis='y', which='both', left=False, right=False, labelleft=False)
plt.title("Ansers length of Closed and Open ended answers")
plt.show()

# %%
rfids = ['009', '008', '007', '035', '036', '037', '441'] + ['386', '387', '395', '396']
relevant = fid_list[fid_list['fid'].isin(rfids)]
relevant.to_pickle('fid_list_analysis.pickle')
fid_statistics.to_pickle('fid_statistics.pickle')
