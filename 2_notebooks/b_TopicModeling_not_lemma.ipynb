# %%
import os
import pandas as pd
from pprint import pprint
from tqdm import tqdm
from spacy.tokens import Token
from spacy.language import Language
import gensim
import gensim.corpora as corpora
from gensim.corpora.dictionary import Dictionary
from gensim.models import LdaMulticore
from gensim.models import CoherenceModel
from matplotlib.patches import FancyBboxPatch
import re
import pyLDAvis
import pyLDAvis.gensim_models as gensimvi
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import math
colors = ["#06005c",
"#6b0062",
"#ac0059",
"#dc2246",
"#f8682c",
"#ffa600"]

# DETECT NON ALPHANUMERIC
def get_excluded(token):
    # Getter function to determine if the token is excluded
    return bool(re.match(r'\W+', token.text))
Token.set_extension('is_excluded', getter=get_excluded, force=True)

plt.rcParams['axes.facecolor'] = 'silver'

# %%
def get_term_frequency(answer):
    term_frequency = {}
    for word in answer:
        count = term_frequency.get(word, 0)
        term_frequency[word] = count + 1
    return term_frequency

def create_frequency_dict(answers):
    frequency_dict = {}
    for answer in answers:
        term_frequency = get_term_frequency(answer)
        for word, frequency in term_frequency.items():
            count = frequency_dict.get(word, 0)
            frequency_dict[word] = count + frequency
    return frequency_dict

def topics_to_graph(lda_model, plot_title=None, filename=None):
    columns = 3
    rows = math.ceil(len(lda_model.print_topics()) / columns)
    # fig, axes = plt.subplots(rows, columns, figsize=(10, 3 * rows))
    fig = plt.figure(figsize=(10, 3 * rows))
    # fig.tight_layout(pad=3)
    
    gs1 = gridspec.GridSpec(rows, columns)

    for i, topic in enumerate(lda_model.print_topics()):
        ax = fig.add_subplot(gs1[i])
        term_scores = re.findall(r'\d{1}.\d+\*"\w+"', topic[1])
        scores = [float(re.findall(r"\d{1}.\d+", score)[0]) for score in term_scores]
        labels = [re.findall(r"[a-zA-Z]+", score)[0] for score in term_scores]
        y_pos = np.arange(len(labels))

        ax.grid(zorder=0)
        ax.barh(y_pos, scores, zorder=2, color=colors[i%6], align='center')
        ax.set_yticks(y_pos)
        ax.set_yticklabels(labels)
        ax.invert_yaxis()
        
        title = ax.set_title(i+1)

    plt.tight_layout()
    if filename:
        plt.savefig(filename, bbox_inches='tight', dpi=300)
    plt.show()

def get_coherence_scores(corpus, dictionary, tokens, coherence_model):
    topics_cv = np.arange(1, 20, 1)
    score_cv = []
    for n_topics in topics_cv:
        lda_model_= LdaMulticore(corpus=corpus, id2word=dictionary, iterations=10, num_topics=n_topics, workers = 4, passes=10, random_state=100)
        cm = CoherenceModel(model=lda_model_, texts=tokens, corpus=corpus, dictionary=dictionary, coherence=coherence_model)
        score_cv.append(cm.get_coherence())
        
    return topics_cv, score_cv
    
def coherence_plot(x, y, plot_title=None, filename=None):
    plt.plot(x, y, color=colors[-1])
    plt.xlabel('Number of Topics')
    plt.ylabel('Coherence Score')
    plt.xticks(x)
    if plot_title:
        plt.title(plot_title)
    plt.grid()
    if filename:
        plt.savefig(filename)
    plt.show()

# %%
oefid = ['009']
oefid_alt = ['009', '037', '441']
cefid = ['386']
cefid_alt = ['386', '387', '395', '396']

# %%
fid_list = pd.read_pickle('fid_list_analysis.pickle')
fid_statistics = pd.read_pickle('fid_statistics.pickle')

# %% [markdown]
# # Open ended

# %%
open_ended = fid_list[fid_list['fid'].isin(oefid)]
open_ended_alt = fid_list[fid_list['fid'].isin(oefid_alt)]

# %% [markdown]
# ## Get Tokens

# %%
def get_doc_tokens(doc):
    removal= ['ADV','PRON','CCONJ','PUNCT','PART','DET','ADP','SPACE', 'NUM', 'SYM']
    return [token.orth_.lower() for token in doc if token.pos_ not in removal and not token.is_stop and token.is_alpha]

# %%
open_ended['tokens'] = open_ended['doc'].apply(get_doc_tokens)
# Out:
# /home/polayala/.venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## Create dictionary and corups

# %%
open_dictionary = Dictionary(open_ended['tokens'])
open_corpus = [open_dictionary.doc2bow(doc) for doc in open_ended['tokens']]

# %% [markdown]
# ##  Train

# %%
open_lda_model = LdaMulticore(corpus=open_corpus, id2word=open_dictionary, iterations=50, num_topics=8, workers = 4, passes=10)

# %% [markdown]
# ## Coherence

# %% [markdown]
# ### C_v

# %%
topics_cv, score_cv = get_coherence_scores(open_corpus, open_dictionary, open_ended['tokens'], coherence_model='c_v')

# %%
coherence_plot(topics_cv, score_cv, plot_title='Open ended Coherence')

# %% [markdown]
# ## Print Topics

# %%
# topics_to_graph(open_lda_model, plot_title='Open ended topics', filename='ba_open_ended_MT.png')
topics_to_graph(open_lda_model, plot_title='Open ended topics')

# %%
lda_display = pyLDAvis.gensim_models.prepare(open_lda_model, open_corpus, open_dictionary)
pyLDAvis.display(lda_display)
# Out:
# /home/polayala/.venv/lib/python3.7/site-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el177091405299112041764141203893"></div>
# <script type="text/javascript">
#
# var ldavis_el177091405299112041764141203893_data = {"mdsDat": {"x": [0.10850643163014997, 0.07902578813121373, -0.12222083351130794, 0.05326230193202191, -0.021120070161404433, -0.0031839953740329646, -0.04175415775505731, -0.05251546489158293], "y": [-0.014546679260494666, -0.06514158475272053, -0.12606196917340298, -0.022670310900108636, 0.017596266398710352, 0.061400493563213435, 0.0874001714715674, 0.06202361265323552], "topics": [1, 2, 3, 4, 5, 6, 7, 8], "cluster": [1, 1, 1, 1, 1, 1, 1, 1], "Freq": [40.60149780252469, 22.18853727075205, 9.26626850859155, 8.081087493852337, 7.901580199256928, 5.4916137608339, 4.989002704441529, 1.4804122597470193]}, "tinfo": {"Term": ["education", "students", "use", "think", "new", "evolution", "future", "technological", "improve", "ways", "technology", "good", "devices", "easier", "children", "work", "teachers", "life", "information", "change", "different", "technologies", "people", "means", "wo", "able", "way", "better", "tech", "lot", "problem", "job", "rely", "young", "chance", "games", "problems", "connection", "addiction", "possibilities", "tend", "skills", "key", "giving", "creating", "makes", "contact", "change", "experience", "environment", "uses", "play", "professionals", "leading", "economic", "apply", "gon", "terms", "laptops", "kids", "children", "thanks", "people", "classes", "wo", "age", "technology", "opportunities", "live", "evolution", "educational", "technological", "teachers", "education", "access", "help", "able", "teach", "improve", "harm", "positive", "aspects", "learn", "hand", "social", "students", "resources", "better", "internet", "future", "way", "study", "think", "negative", "information", "learning", "new", "ways", "interactive", "developments", "child", "share", "shared", "tecnology", "afford", "view", "crucial", "course", "improved", "trusted", "wanting", "calculator", "measures", "memorize", "divide", "generation", "period", "anxiety", "short", "motivation", "stress", "controlled", "breath", "fear", "opinion", "pace", "consider", "disagreements", "humanhuman", "impact", "know", "lack", "work", "getting", "useful", "time", "home", "communication", "device", "tools", "positive", "students", "study", "negative", "new", "use", "future", "devices", "information", "technological", "education", "technology", "internet", "aspects", "system", "making", "lot", "learning", "access", "evolution", "improve", "better", "learn", "general", "holograms", "analyze", "results", "text", "editorial", "vr", "supports", "explanations", "watching", "images", "seeing", "illustrative", "covering", "loss", "contents", "misinformation", "animation", "potential", "divulgative", "spreading", "highquality", "assignment", "capable", "accelerated", "higher", "correction", "accomplish", "goals", "comparison", "allow", "public", "tech", "face", "understand", "devices", "use", "knowledge", "students", "start", "quality", "expensive", "platforms", "internet", "people", "example", "work", "positive", "attend", "world", "accessible", "class", "interactive", "information", "improve", "aspects", "technology", "easier", "good", "minors", "private", "upgrading", "adaptive", "helped", "recollected", "hooked", "sector", "limit", "invasion", "important", "upgrade", "bit", "schedules", "smartphones", "risk", "inclusive", "begin", "t", "interaction", "straining", "intelligence", "eyesight", "interestingnegative", "persona", "track", "contains", "powerful", "continuous", "expand", "feel", "number", "possibility", "helps", "automatization", "huge", "life", "increase", "bring", "consequence", "students", "education", "relationship", "lot", "information", "technology", "certain", "example", "access", "aspects", "negative", "time", "accessible", "learning", "impact", "evolution", "studies", "teachers", "internet", "resources", "positive", "people", "webs", "true", "idea", "listen", "handle", "solid", "gotten", "plagarism", "incompetenced", "degree", "robots", "prepare", "mechanisms", "diverse", "booknegatives ...

# %% [markdown]
# #  Close ended

# %%
closed_ended = fid_list[fid_list['fid'].isin(cefid)]
closed_ended_alt = fid_list[fid_list['fid'].isin(cefid_alt)]

# %% [markdown]
# ## Get Tokens

# %%
closed_ended['tokens'] = closed_ended['doc'].apply(get_doc_tokens)
closed_ended
# Out:
# /home/polayala/.venv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#      fid  pid  level  individual_level  \
# 466  386  NaN    0.0                 0
# 467  386  NaN    0.0                 0
# 468  386  NaN    0.0                 0
# 469  386  NaN    0.0                 0
# 470  386  NaN    0.0                 0
# 471  386  NaN    0.0                 0
# 472  386  NaN    0.0                 0
# 473  386  NaN    0.0                 0
# 474  386  NaN    0.0                 0
# 475  386  NaN    0.0                 0
# 476  386  NaN    0.0                 0
# 477  386  NaN    0.0                 0
# 478  386  NaN    0.0                 0
# 479  386  NaN    0.0                 0
# 480  386  NaN    0.0                 0
# 481  386  NaN    1.0                 0
# 482  386  NaN    1.0                 0
# 483  386  NaN    1.0                 0
# 484  386  NaN    1.0                 0
# 485  386  NaN    1.0                 0
# 486  386  NaN    2.0                 0
# 487  386  NaN    2.0                 0
#
#                                              fs_answer  \
# 466  Scalability: The possibility for more NGOs to ...
# 467  Resource access and sharing: Now they have dec...
# 468  Openness and resource sharing are very related...
# 469  Resource access and sharing: they can share th...
# 470  Scalability -> An increase of scalability by m...
# 471  The technologies used by these databases and t...
# 472  In this case we can identify SCALABILITY, as i...
# 473  Heterogeneity -> There is a lot of heterogenei...
# 474  Fault-tolerance: Given the importance of their...
# 475  The main non-functional requirement in this ca...
# 476  Functional requirements:Fault tolerance: " the...
# 477  Scalability-> expected that more NGO join and ...
# 478  Scalability: In the future, it is expected tha...
# 479  Scalability: The NGO needs a scalable software...
# 480  Scalability â†’Openness â†’ the idea of having...
# 481  Openness and resource sharing are very related...
# 482  Resource access and sharing: Now they have dec...
# 483  Scalability: The possibility for more NGOs to ...
# 484  Fault tolerance: " they are worried about the ...
# 485  Scalability: In the future, it is expected tha...
# 486  Scalability: In the future, it is expected tha...
# 487  Fault tolerance: " they are worried about the ...
#
#                                            standarized lang  \
# 466  scalability: the possibility for more ngos to ...   en
# 467  resource access and sharing: now they have dec...   en
# 468  openness and resource sharing are very related...   en
# 469  resource access and sharing: they can share th...   en
# 470  scalability > an increase of scalability by ma...   en
# 471  the technologies used by these databases and t...   en
# 472  in this case we can identify scalability, as i...   en
# 473  heterogeneity > there is a lot of heterogeneit...   en
# 474  faulttolerance: given the importance of their ...   en
# 475  the main nonfunctional requirement in this cas...   en
# 476  functional requirements:fault tolerance: " the...   en
# 477  scalability> expected that more ngo join and s...   en
# 478  scalability: in the future, it is expected tha...   en
# 479  scalability: the ngo needs a scalable software...   en
# 480  scalability â†’openness â†’ the idea of having...   en
# 481  openness and resource sharing are very related...   en
# 482  resource access and sharing: now they have dec...   en
# 483  scalability: the possibility for more ngos to ...   en
# 484  fault tolerance: " they are worried about the ...   en
# 485  scalability: in the future, it is expected tha...   en
# 486  scalability: in the future, it is expected tha...   en
# 487  fault tolerance: " they are worried about the ...   en
#
#                                                    doc  length  length_clean  \
# 466  (scalability, :, the, possibility, for, more, ...      78            68
# 467  (resource, access, and, sharing, :, now, they,...     107            99
# 468  (openness, and, resource, sharing, are, very, ...     315           289
# 469  (resource, access, and, sharing, :, they, can,...      38            32
# 470  (scalability, >, an, increase, of, scalability...      91            83
# 471  (the, technologies, used, by, these, databases...      63            58
# 472  (in, this, case, we, can, identify, scalabilit...      91            90
# 473  (heterogeneity, >, there, is, a, lot, of, hete...     177           159
# 474  (faulttolerance, :, given, the, importance, of...      58            54
# 475  (the, main, nonfunctional, requirement, in, th...     224           202
# 476  (functional, requirements, :, fault, tolerance...      82            73
# 477  (scalability, >, expected, that, more, ngo, jo...      50            45
# 478  (scalability, :, in, the, future, ,, it, is, e...     144           135
# 479  (scalability, :, the, ngo, needs, a, scalable,...     111            95
# 480  (scalability, â†’openness, â†, ’, the, idea, o...     105            91
# 481  (openness, and, resource, sharing, are, very, ...     342           310
# 482  (resource, access, and, sharing, :, now, they,...     183           168
# 483  (scalability, :, the, possibility, for, more, ...      78            68
# 484  (fault, tolerance, :, ", they, are, worried, a...     106            93
# 485  (scalability, :, in, the, future, ,, it, is, e...     181           170
# 486  (scalability, :, in, the, future, ,, it, is, e...     185           174
# 487  (fault, tolerance, :, ", they, are, worried, a...     106            93
#
#      length_special task_type  \
# 466              10     Close
# 467               8     Close
# 468              26     Close
# 469               6     Close
# 470               8     Close
# 471               5     Close
# 472               1     Close
# 473              18     Close
# 474               4     Close
# 475              22     Close
# 476               9     Close
# 477               5     Close
# 478               9     Close
# 479              16     Close
# 480              14     Close
# 481              32     Close
# 482              15     Close
# 483              10     Close
# 484              13     Close
# 485              11     Close
# 486              11     Close
# 487              13     Close
#
#                                                 tokens
# 466  [scalability, possibility, ngos, join, effort,...
# 467  [resource, access, sharing, decided, join, eff...
# 468  [openness, resource, sharing, related, second,...
# 469  [resource, access, sharing, share, data, colle...
# 470  [scalability, increase, scalability, making, p...
# 471  [technologies, databases, tools, diverse, hete...
# 472  [case, identify, scalability, able, adapt, new...
# 473  [heterogeneity, lot, heterogeneity, ngo, shari...
# 474  [faulttolerance, given, importance, actions, w...
# 475  [main, nonfunctional, requirement, case, resou...
# 476  [functional, requirements, fault, tolerance, w...
# 477  [scalability, expected, ngo, join, sable, add,...
# 478  [scalability, future, expected, ngos, join, li...
# 479  [scalability, ngo, needs, scalable, software, ...
# 480  [scalability, idea, having, application, order...
# 481  [openness, resource, sharing, related, second,...
# 482  [resource, access, sharing, decided, join, eff...
# 483  [scalability, possibility, ngos, join, effort,...
# 484  [fault, tolerance, worried, problems, emerge, ...
# 485  [scalability, future, expected, ngos, join, li...
# 486  [scalability, future, expected, ngos, join, li...
# 487  [fault, tolerance, worried, problems, emerge, ...

# %% [markdown]
# ## Create dictionary and corups

# %%
closed_dictionary = Dictionary(closed_ended['tokens'])
closed_corpus = [closed_dictionary.doc2bow(doc) for doc in closed_ended['tokens']]

# %% [markdown]
# ##  Train

# %%
closed_lda_model = LdaMulticore(corpus=closed_corpus, id2word=closed_dictionary, iterations=50, num_topics=9, workers = 4, passes=10)

# %% [markdown]
# ## Coherence

# %% [markdown]
# ### C_v

# %%
topics_cv, score_cv = get_coherence_scores(closed_corpus, closed_dictionary, closed_ended['tokens'], coherence_model='c_v')

# %%
coherence_plot(topics_cv, score_cv, plot_title='Close ended coherence score')

# %% [markdown]
# ## Print Topics

# %%
# topics_to_graph(closed_lda_model, plot_title='Close ended topics', filename='ba_close_ended_MT.png')
topics_to_graph(closed_lda_model, plot_title='Close ended topics')

# %%
lda_display = pyLDAvis.gensim_models.prepare(closed_lda_model, closed_corpus, closed_dictionary)
pyLDAvis.display(lda_display)
# Out:
# /home/polayala/.venv/lib/python3.7/site-packages/pyLDAvis/_prepare.py:247: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   by='saliency', ascending=False).head(R).drop('saliency', 1)
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.3.1/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el177091405315775316002056065152"></div>
# <script type="text/javascript">
#
# var ldavis_el177091405315775316002056065152_data = {"mdsDat": {"x": [0.00031789126995651216, 0.05830422413147676, 0.15249882362990694, 0.15788526403174102, -0.10508565212970332, -0.006854296548743236, -0.08555285432031254, -0.08591150572846044, -0.085601894335862], "y": [-0.10467271019262903, 0.11504840813161547, 0.013567391880013366, -0.0555465877448786, 0.06558290000729314, 0.05082281193633092, -0.028202899362562168, -0.02833256510250936, -0.02826674955267385], "topics": [1, 2, 3, 4, 5, 6, 7, 8, 9], "cluster": [1, 1, 1, 1, 1, 1, 1, 1, 1], "Freq": [27.89892219692157, 26.26083084740185, 17.194165495784624, 16.441837328209385, 6.361765415775726, 5.186244245128592, 0.21874482456287725, 0.21874482310768573, 0.21874482310768573]}, "tinfo": {"Term": ["ngo", "system", "software", "actions", "database", "offer", "ong", "ngos", "planning", "worried", "openness", "adapted", "network", "given", "importance", "efforts", "tool", "important", "need", "needs", "expected", "data", "like", "effort", "application", "want", "duplicate", "order", "know", "resource", "available", "extended", "systems", "making", "goal", "computer", "replication", "mediated", "services", "second", "presence", "characteristic", "shared", "variety", "means", "pilot", "reimplemented", "desired", "achieve", "information", "specifying", "faulttolerant", "platforms", "key", "determines", "interface", "cycle", "related", "ones", "operations", "requirements", "openness", "distributed", "ways", "system", "software", "ngos", "resources", "stated", "users", "case", "join", "data", "efforts", "sharing", "database", "share", "application", "resource", "offer", "planning", "ngo", "needs", "future", "tool", "effort", "expected", "adapted", "tolerance", "ability", "diversescalability", "possibility", "concern", "mentionedtransparency", "mentioned", "minimum", "ongs", "transparency", "dataheterogeneity", "failsconcurrency", "datafaulttolerance", "openess", "diverseresource", "fail", "heterogenitythey", "sharinganother", "tolerancetry", "degree", "wish", "trying", "tolerant", "major", "equipment", "lot", "running", "failure", "accessing", "worth", "collaborate", "database", "effort", "adapted", "problem", "databases", "access", "having", "resource", "ngo", "system", "tools", "ngos", "technologies", "problems", "sharing", "tool", "network", "tolerance", "planning", "emerge", "ong", "join", "use", "needs", "data", "duplicate", "scalability", "fault", "worried", "understand", "client", "example", "servicesheterogeneity", "thing", "concurrency", "continuouslyheterogeneity", "tolerence", "diverseconcurrency", "important", "ong", "place", "particular", "better", "operating", "know", "like", "overall", "fails", "enable", "duplicate", "places", "future", "coordinate", "help", "offer", "expected", "collect", "problem", "application", "data", "access", "collaborative", "ngos", "planning", "tool", "share", "software", "use", "emerge", "sharing", "worried", "problems", "technologies", "tools", "join", "given", "importance", "decided", "higher", "depending", "extend", "needed", "theproblems", "implement", "actions", "need", "like", "different", "offer", "places", "coordinate", "help", "enable", "collaborative", "worried", "faulttolerance", "application", "tool", "use", "order", "efforts", "emerge", "collect", "overall", "ways", "network", "access", "software", "planning", "data", "problems", "ngo", "share", "sharing", "resource", "join", "required", "text", "order", "effortsfaulttolerance", "piloting", "easy", "effortsconcurrency", "collected", "moretransparency", "toolheterogeneity", "said", "idea", "havedecided", "time", "purposes", "following", "lines", "requirement", "nonfunctional", "work", "emergency", "main", "multiple", "having", "couple", "collaboration", "want", "ngo", "needs", "users", "adapted", "planning", "data", "share", "database", "application", "scalability", "enable", "access", "collaborative", "join", "sharing", "tool", "future", "expected", "fault", "tolerance", "duplicate" ...
